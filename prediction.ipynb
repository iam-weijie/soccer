# %% [markdown]
# <a href="https://colab.research.google.com/github/iam-weijie/soccer/blob/main/prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
matches = pd.read_csv("matches.csv", index_col = 0)
matches.head()
# Out:
#           Date   Time          Comp        Round  Day Venue Result   GF   GA  \
# 5   2023-09-19  21:00  Champions Lg  Group stage  Tue  Away      L  0.0  2.0
# 8   2023-10-04  21:00  Champions Lg  Group stage  Wed  Home      D  0.0  0.0
# 11  2023-10-25  20:00  Champions Lg  Group stage  Wed  Away      W  1.0  0.0
# 15  2023-11-07  18:45  Champions Lg  Group stage  Tue  Home      W  2.0  0.0
# 18  2023-11-28  21:00  Champions Lg  Group stage  Tue  Away      W  3.0  1.0
#
#              Opponent  ...  Match Report  Notes    Sh  SoT  Dist   FK PK  \
# 5        fr Paris S-G  ...  Match Report    NaN  14.0  1.0  19.0  0.0  0
# 8            it Milan  ...  Match Report    NaN  18.0  3.0  20.2  2.0  0
# 11  eng Newcastle Utd  ...  Match Report    NaN  13.0  5.0  17.4  0.0  0
# 15  eng Newcastle Utd  ...  Match Report    NaN  17.0  8.0  19.6  0.0  0
# 18           it Milan  ...  Match Report    NaN  11.0  3.0  18.7  0.0  1
#
#    PKatt Season      Team
# 5      0   2024  Dortmund
# ...

# %%
matches.shape
# Out:
# (520, 27)

# %%
matches["Team"].value_counts()
# Out:
# Team
# FC Copenhagen          28
# PSV Eindhoven          24
# Galatasaray            24
# Dortmund               20
# Atletico Madrid        20
# Barcelona              20
# Braga                  20
# Paris Saint Germain    20
# Manchester City        18
# Real Madrid            18
# Bayern Munich          18
# Arsenal                18
# Antwerp                16
# Real Sociedad          16
# Napoli                 16
# Lazio                  16
# RB Leipzig             16
# Internazionale         16
# Porto                  16
# Young Boys             16
# Red Bull Salzburg      12
# Sevilla                12
# Union Berlin           12
# Celtic                 12
# Shakhtar Donetsk       12
# Benfica                12
# Manchester United      12
# Newcastle United       12
# Feyenoord              12
# Lens                   12
# Milan                  12
# Red Star Belgrade      12
# Name: count, dtype: int64

# %%
matches[matches["Team"] == "Red Bull Salzburg"].sort_values("Date")
# Out:
#           Date   Time          Comp        Round  Day Venue Result   GF   GA  \
# 7   2023-09-20  20:00  Champions Lg  Group stage  Wed  Away      W  2.0  0.0
# 7   2023-09-20  20:00  Champions Lg  Group stage  Wed  Away      W  2.0  0.0
# 10  2023-10-03  18:45  Champions Lg  Group stage  Tue  Home      L  0.0  2.0
# 10  2023-10-03  18:45  Champions Lg  Group stage  Tue  Home      L  0.0  2.0
# 13  2023-10-24  18:45  Champions Lg  Group stage  Tue  Away      L  1.0  2.0
# 13  2023-10-24  18:45  Champions Lg  Group stage  Tue  Away      L  1.0  2.0
# 16  2023-11-08  21:00  Champions Lg  Group stage  Wed  Home      L  0.0  1.0
# 16  2023-11-08  21:00  Champions Lg  Group stage  Wed  Home      L  0.0  1.0
# 19  2023-11-29  21:00  Champions Lg  Group stage  Wed  Away      D  0.0  0.0
# 19  2023-11-29  21:00  Champions Lg  Group stage  Wed  Away      D  0.0  0.0
# 22  2023-12-12  21:00  Champions Lg  Group stage  Tue  Home      L  1.0  3.0
# ...

# %%
matches["Round"].value_counts()
# Out:
# Round
# Group stage                384
# Round of 16                 64
# Quarter-finals              24
# Play-off round              24
# Third qualifying round      16
# Second qualifying round      8
# Name: count, dtype: int64

# %%
del matches["Comp"]
del matches["Notes"]
matches.dtypes
# Out:
# Date             object
# Time             object
# Round            object
# Day              object
# Venue            object
# Result           object
# GF               object
# GA               object
# Opponent         object
# xG              float64
# xGA             float64
# Poss            float64
# Attendance      float64
# Captain          object
# Formation        object
# Referee          object
# Match Report     object
# Sh              float64
# SoT             float64
# Dist            float64
# FK              float64
# PK                int64
# PKatt             int64
# Season            int64
# Team             object
# dtype: object

# %%
# convert object-type to numeric
matches["Date"] = pd.to_datetime(matches["Date"])

# %%
matches.dtypes
# Out:
# Date            datetime64[ns]
# Time                    object
# Round                   object
# Day                     object
# Venue                   object
# Result                  object
# GF                      object
# GA                      object
# Opponent                object
# xG                     float64
# xGA                    float64
# Poss                   float64
# Attendance             float64
# Captain                 object
# Formation               object
# Referee                 object
# Match Report            object
# Sh                     float64
# SoT                    float64
# Dist                   float64
# FK                     float64
# PK                       int64
# PKatt                    int64
# Season                   int64
# Team                    object
# dtype: object

# %%
matches["Venue_code"] = matches["Venue"].astype("category").cat.codes

# %%
matches["Opp_code"] = matches["Opponent"].astype("category").cat.codes

# %%
matches["Hour"] = matches["Time"].str.replace(":.+", "", regex=True).astype("int")
matches["Day_code"] = matches["Date"].dt.dayofweek

# %%
matches["Target"] = (matches["Result"]=="W").astype("int")

# %%
matches
# Out:
#          Date   Time        Round  Day Venue Result   GF   GA  \
# 5  2023-09-19  21:00  Group stage  Tue  Away      L  0.0  2.0
# 8  2023-10-04  21:00  Group stage  Wed  Home      D  0.0  0.0
# 11 2023-10-25  20:00  Group stage  Wed  Away      W  1.0  0.0
# 15 2023-11-07  18:45  Group stage  Tue  Home      W  2.0  0.0
# 18 2023-11-28  21:00  Group stage  Tue  Away      W  3.0  1.0
# ..        ...    ...          ...  ...   ...    ...  ...  ...
# 9  2023-10-04  21:00  Group stage  Wed  Home      D    2    2
# 12 2023-10-25  21:00  Group stage  Wed  Away      L    1    3
# 16 2023-11-07  21:00  Group stage  Tue  Home      L    1    2
# 19 2023-11-28  21:00  Group stage  Tue  Away      L    0    2
# 22 2023-12-13  18:45  Group stage  Wed  Home      L    2    3
#
#                Opponent   xG  ...   FK  PK  PKatt Season               Team  \
# 5          fr Paris S-G  0.7  ...  0.0   0      0   2024           Dortmund
# ...

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["Date"] < "2024-01-01"]

# %%
test = matches[matches["Date"] > "2024-01-01"]

# %%
predictors = ["Venue_code", "Opp_code", "Hour", "Day_code"]

# %%
rf.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
acc = accuracy_score(test["Target"], preds)

# %%
acc
# Out:
# 0.6136363636363636

# %%
combined = pd.DataFrame(dict(actual=test["Target"],prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           44  10
# 1           24  10

# %%
precision_score(test["Target"], preds)
# Out:
# 0.5

# %%
grouped_matches = matches.groupby("Team")
group = grouped_matches.get_group("Paris Saint Germain")

# %%
group
# Out:
#          Date   Time           Round  Day Venue Result   GF   GA  \
# 5  2023-09-19  21:00     Group stage  Tue  Home      W  2.0  0.0
# 8  2023-10-04  20:00     Group stage  Wed  Away      L  1.0  4.0
# 11 2023-10-25  21:00     Group stage  Wed  Home      W  3.0  0.0
# 14 2023-11-07  21:00     Group stage  Tue  Away      L  1.0  2.0
# 17 2023-11-28  21:00     Group stage  Tue  Home      D  1.0  1.0
# 20 2023-12-13  21:00     Group stage  Wed  Away      D  1.0  1.0
# 31 2024-02-14  21:00     Round of 16  Wed  Home      W  2.0  0.0
# 35 2024-03-05  21:00     Round of 16  Tue  Away      W  2.0  1.0
# 42 2024-04-10  21:00  Quarter-finals  Wed  Home      L  2.0  3.0
# 43 2024-04-16  21:00  Quarter-finals  Tue  Away      W  4.0  1.0
# 5  2023-09-19  21:00     Group stage  Tue  Home      W  2.0  0.0
# 8  2023-10-04  20:00     Group stage  Wed  Away      L  1.0  4.0
# 11 2023-10-25  21:00     Group stage  Wed  Home      W  3.0  0.0
# ...

# %%
def rolling_averages(group, cols, new_cols):
  group = group.sort_values("Date")
  group[cols] = group[cols].apply(pd.to_numeric, errors='coerce')
  rolling_stats = group[cols].rolling(3, closed="left").mean()
  group[new_cols] = rolling_stats
  group = group.dropna(subset=new_cols)
  return group

# %%
cols = ["GF","GA","Sh","SoT", "Dist","FK","PK","PKatt"]

# %%
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['GF_rolling',
#  'GA_rolling',
#  'Sh_rolling',
#  'SoT_rolling',
#  'Dist_rolling',
#  'FK_rolling',
#  'PK_rolling',
#  'PKatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          Date   Time           Round  Day Venue Result   GF   GA  \
# 8  2023-10-04  20:00     Group stage  Wed  Away      L  1.0  4.0
# 11 2023-10-25  21:00     Group stage  Wed  Home      W  3.0  0.0
# 11 2023-10-25  21:00     Group stage  Wed  Home      W  3.0  0.0
# 14 2023-11-07  21:00     Group stage  Tue  Away      L  1.0  2.0
# 14 2023-11-07  21:00     Group stage  Tue  Away      L  1.0  2.0
# 17 2023-11-28  21:00     Group stage  Tue  Home      D  1.0  1.0
# 17 2023-11-28  21:00     Group stage  Tue  Home      D  1.0  1.0
# 20 2023-12-13  21:00     Group stage  Wed  Away      D  1.0  1.0
# 20 2023-12-13  21:00     Group stage  Wed  Away      D  1.0  1.0
# 31 2024-02-14  21:00     Round of 16  Wed  Home      W  2.0  0.0
# 31 2024-02-14  21:00     Round of 16  Wed  Home      W  2.0  0.0
# 35 2024-03-05  21:00     Round of 16  Tue  Away      W  2.0  1.0
# 35 2024-03-05  21:00     Round of 16  Tue  Away      W  2.0  1.0
# ...

# %%
matches_rolling = grouped_matches.apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                     Date   Time        Round  Day Venue Result   GF   GA  \
# Team
# Antwerp    12 2023-10-04  18:45  Group stage  Wed  Home      L  2.0  3.0
#            15 2023-10-25  21:00  Group stage  Wed  Home      L  1.0  4.0
#            15 2023-10-25  21:00  Group stage  Wed  Home      L  1.0  4.0
#            18 2023-11-07  20:00  Group stage  Tue  Away      L  0.0  2.0
#            18 2023-11-07  20:00  Group stage  Tue  Away      L  0.0  2.0
# ...                  ...    ...          ...  ...   ...    ...  ...  ...
# Young Boys 11 2023-10-04  21:00  Group stage  Wed  Away      D  2.0  2.0
#            14 2023-10-25  21:00  Group stage  Wed  Home      L  1.0  3.0
#            14 2023-10-25  21:00  Group stage  Wed  Home      L  1.0  3.0
#            17 2023-11-07  20:00  Group stage  Tue  Away      L  0.0  3.0
#            24 2023-12-13  18:45  Group stage  Wed  Away      L  1.0  2.0
#
#                           Opponent   xG  ...  Day_code  Target  GF_rolling  \
# ...

# %%
matches_rolling.droplevel("Team")
# Out:
#          Date   Time        Round  Day Venue Result   GF   GA  \
# 12 2023-10-04  18:45  Group stage  Wed  Home      L  2.0  3.0
# 15 2023-10-25  21:00  Group stage  Wed  Home      L  1.0  4.0
# 15 2023-10-25  21:00  Group stage  Wed  Home      L  1.0  4.0
# 18 2023-11-07  20:00  Group stage  Tue  Away      L  0.0  2.0
# 18 2023-11-07  20:00  Group stage  Tue  Away      L  0.0  2.0
# ..        ...    ...          ...  ...   ...    ...  ...  ...
# 11 2023-10-04  21:00  Group stage  Wed  Away      D  2.0  2.0
# 14 2023-10-25  21:00  Group stage  Wed  Home      L  1.0  3.0
# 14 2023-10-25  21:00  Group stage  Wed  Home      L  1.0  3.0
# 17 2023-11-07  20:00  Group stage  Tue  Away      L  0.0  3.0
# 24 2023-12-13  18:45  Group stage  Wed  Away      L  1.0  2.0
#
#                Opponent   xG  ...  Day_code  Target  GF_rolling GA_rolling  \
# 12          ua Shakhtar  1.8  ...         2       0    0.666667   4.333333
# ...

# %%
matches_rolling.index=range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#           Date   Time        Round  Day Venue Result   GF   GA  \
# 0   2023-10-04  18:45  Group stage  Wed  Home      L  2.0  3.0
# 1   2023-10-25  21:00  Group stage  Wed  Home      L  1.0  4.0
# 2   2023-10-25  21:00  Group stage  Wed  Home      L  1.0  4.0
# 3   2023-11-07  20:00  Group stage  Tue  Away      L  0.0  2.0
# 4   2023-11-07  20:00  Group stage  Tue  Away      L  0.0  2.0
# ..         ...    ...          ...  ...   ...    ...  ...  ...
# 358 2023-10-04  21:00  Group stage  Wed  Away      D  2.0  2.0
# 359 2023-10-25  21:00  Group stage  Wed  Home      L  1.0  3.0
# 360 2023-10-25  21:00  Group stage  Wed  Home      L  1.0  3.0
# 361 2023-11-07  20:00  Group stage  Tue  Away      L  0.0  3.0
# 362 2023-12-13  18:45  Group stage  Wed  Away      L  1.0  2.0
#
#                 Opponent   xG  ...  Day_code  Target  GF_rolling GA_rolling  \
# 0            ua Shakhtar  1.8  ...         2       0    0.666667   4.333333
# ...

# %%
def make_predictions(data, predictors):
  train = data[data["Date"] < "2024-01-01"]
  test = data[data["Date"] > "2024-01-01"]
  rf.fit(train[predictors], train["Target"])
  preds = rf.predict(test[predictors])
  combined = pd.DataFrame(dict(actual=test["Target"], predicted=preds), index=test.index)
  precision = precision_score(test["Target"], preds)
  return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.6666666666666666

# %%
combined
# Out:
#      actual  predicted
# 18        0          0
# 19        0          0
# 20        1          0
# 30        0          1
# 31        0          0
# ..      ...        ...
# 299       0          0
# 309       0          0
# 310       0          0
# 311       0          0
# 312       0          0
#
# [79 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["Date", "Team", "Opponent", "Result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#      actual  predicted       Date             Team             Opponent Result
# 18        0          0 2024-02-21          Arsenal             pt Porto      L
# 19        0          0 2024-02-21          Arsenal             pt Porto      L
# 20        1          0 2024-03-12          Arsenal             pt Porto      W
# 30        0          1 2024-02-20  Atletico Madrid             it Inter      L
# 31        0          0 2024-02-20  Atletico Madrid             it Inter      L
# ..      ...        ...        ...              ...                  ...    ...
# 299       0          0 2024-04-09      Real Madrid  eng Manchester City      D
# 309       0          0 2024-02-14    Real Sociedad         fr Paris S-G      L
# 310       0          0 2024-02-14    Real Sociedad         fr Paris S-G      L
# 311       0          0 2024-03-05    Real Sociedad         fr Paris S-G      L
# 312       0          0 2024-03-05    Real Sociedad         fr Paris S-G      L
#
# [79 rows x 6 columns]

# %%
# Next steps (possible ways to improve the prediction):
# scrape more data (more seasons)
# use more columns
# use data from outside the league
