# %% [markdown]
# <a href="https://colab.research.google.com/github/iam-weijie/soccer/blob/main/scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
standings_url = "https://fbref.com/en/comps/8/Champions-League-Stats"

# %%
data = requests.get(standings_url)

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select('table.stats_table')[8]

# %%
links = standings_table.find_all('a') # `find_all` finds tags

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if '/squads/' in l]
links
# Out:
# ['/en/squads/add600ae/Dortmund-Stats',
#  '/en/squads/e2d8892c/Paris-Saint-Germain-Stats',
#  '/en/squads/b8fd03ef/Manchester-City-Stats',
#  '/en/squads/53a2f082/Real-Madrid-Stats',
#  '/en/squads/db3b9613/Atletico-Madrid-Stats',
#  '/en/squads/054efa67/Bayern-Munich-Stats',
#  '/en/squads/206d90db/Barcelona-Stats',
#  '/en/squads/18bb7c10/Arsenal-Stats',
#  '/en/squads/5e876ee6/Porto-Stats',
#  '/en/squads/d609edc0/Internazionale-Stats',
#  '/en/squads/acbb6a5b/RB-Leipzig-Stats',
#  '/en/squads/7213da33/Lazio-Stats',
#  '/en/squads/e31d1cd9/Real-Sociedad-Stats',
#  '/en/squads/d48ad4ff/Napoli-Stats',
#  '/en/squads/e334d850/PSV-Eindhoven-Stats',
#  '/en/squads/18050b20/FC-Copenhagen-Stats',
#  '/en/squads/e89d5a28/Shakhtar-Donetsk-Stats',
#  '/en/squads/dc56fe14/Milan-Stats',
#  '/en/squads/fd4e0f7d/Lens-Stats',
#  '/en/squads/fb4ca611/Feyenoord-Stats',
#  '/en/squads/b2b47a98/Newcastle-United-Stats',
#  '/en/squads/ecd11ca2/Galatasaray-Stats',
# ...

# %%
team_urls = [f"https://fbref.com{l}" for l in links] # turn links into urls
team_urls
# Out:
# ['https://fbref.com/en/squads/add600ae/Dortmund-Stats',
#  'https://fbref.com/en/squads/e2d8892c/Paris-Saint-Germain-Stats',
#  'https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/53a2f082/Real-Madrid-Stats',
#  'https://fbref.com/en/squads/db3b9613/Atletico-Madrid-Stats',
#  'https://fbref.com/en/squads/054efa67/Bayern-Munich-Stats',
#  'https://fbref.com/en/squads/206d90db/Barcelona-Stats',
#  'https://fbref.com/en/squads/18bb7c10/Arsenal-Stats',
#  'https://fbref.com/en/squads/5e876ee6/Porto-Stats',
#  'https://fbref.com/en/squads/d609edc0/Internazionale-Stats',
#  'https://fbref.com/en/squads/acbb6a5b/RB-Leipzig-Stats',
#  'https://fbref.com/en/squads/7213da33/Lazio-Stats',
#  'https://fbref.com/en/squads/e31d1cd9/Real-Sociedad-Stats',
#  'https://fbref.com/en/squads/d48ad4ff/Napoli-Stats',
#  'https://fbref.com/en/squads/e334d850/PSV-Eindhoven-Stats',
#  'https://fbref.com/en/squads/18050b20/FC-Copenhagen-Stats',
# ...

# %%
team_url = team_urls[0]
data = requests.get(team_url)

# %%
matches = pd.read_html(data.text, match="Scores & Fixtures")
matches[0].head()
# Out:
#          Date   Time        Comp        Round  Day Venue Result   GF   GA  \
# 0  2023-08-12  15:30   DFB-Pokal  Round of 64  Sat  Away      W  6.0  1.0
# 1  2023-08-19  18:30  Bundesliga  Matchweek 1  Sat  Home      W  1.0  0.0
# 2  2023-08-26  15:30  Bundesliga  Matchweek 2  Sat  Away      D  1.0  1.0
# 3  2023-09-01  20:30  Bundesliga  Matchweek 3  Fri  Home      D  2.0  2.0
# 4  2023-09-16  15:30  Bundesliga  Matchweek 4  Sat  Away      W  4.0  2.0
#
#            Opponent   xG  xGA  Poss  Attendance   Captain Formation  \
# 0  TSV Schott Mainz  NaN  NaN  73.0     30312.0  Emre Can   4-2-3-1
# 1              Köln  1.8  1.2  66.0     81365.0  Emre Can   4-2-3-1
# 2            Bochum  1.3  1.0  64.0     26000.0  Emre Can   4-1-4-1
# 3        Heidenheim  3.4  2.1  62.0     81365.0  Emre Can     4-3-3
# 4          Freiburg  2.3  1.0  50.0     34700.0  Emre Can     4-3-3
#
#            Referee  Match Report Notes
# 0   Benjamin Brand  Match Report   NaN
# ...

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting' in l]
links
# Out:
# ['/en/squads/add600ae/2023-2024/matchlogs/all_comps/shooting/Dortmund-Match-Logs-All-Competitions',
#  '/en/squads/add600ae/2023-2024/matchlogs/all_comps/shooting/Dortmund-Match-Logs-All-Competitions',
#  '/en/squads/add600ae/2023-2024/matchlogs/all_comps/shooting/Dortmund-Match-Logs-All-Competitions',
#  '/en/squads/add600ae/2023-2024/matchlogs/all_comps/shooting/Dortmund-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
shooting = pd.read_html(data.text, match = "Shooting")[0]
shooting.head()
# Out:
#   For Dortmund                                                              \
#           Date   Time        Comp        Round  Day Venue Result   GF   GA
# 0   2023-08-12  15:30   DFB-Pokal  Round of 64  Sat  Away      W  6.0  1.0
# 1   2023-08-19  18:30  Bundesliga  Matchweek 1  Sat  Home      W  1.0  0.0
# 2   2023-08-26  15:30  Bundesliga  Matchweek 2  Sat  Away      D  1.0  1.0
# 3   2023-09-01  20:30  Bundesliga  Matchweek 3  Fri  Home      D  2.0  2.0
# 4   2023-09-16  15:30  Bundesliga  Matchweek 4  Sat  Away      W  4.0  2.0
#
#                      ... Standard               Expected                    \
#            Opponent  ...     Dist   FK PK PKatt       xG npxG npxG/Sh G-xG
# 0  TSV Schott Mainz  ...      NaN  NaN  0     0      NaN  NaN     NaN  NaN
# 1              Köln  ...     12.5  0.0  0     0      1.8  1.8    0.16 -0.8
# 2            Bochum  ...     15.4  0.0  0     0      1.3  1.3    0.09 -0.3
# ...

# %%
shooting.columns = shooting.columns.droplevel()
shooting.head()
# Out:
#          Date   Time        Comp        Round  Day Venue Result   GF   GA  \
# 0  2023-08-12  15:30   DFB-Pokal  Round of 64  Sat  Away      W  6.0  1.0
# 1  2023-08-19  18:30  Bundesliga  Matchweek 1  Sat  Home      W  1.0  0.0
# 2  2023-08-26  15:30  Bundesliga  Matchweek 2  Sat  Away      D  1.0  1.0
# 3  2023-09-01  20:30  Bundesliga  Matchweek 3  Fri  Home      D  2.0  2.0
# 4  2023-09-16  15:30  Bundesliga  Matchweek 4  Sat  Away      W  4.0  2.0
#
#            Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  \
# 0  TSV Schott Mainz  ...   NaN  NaN   0      0  NaN   NaN      NaN   NaN
# 1              Köln  ...  12.5  0.0   0      0  1.8   1.8     0.16  -0.8
# 2            Bochum  ...  15.4  0.0   0      0  1.3   1.3     0.09  -0.3
# 3        Heidenheim  ...  18.3  2.0   1      1  3.4   2.6     0.14  -1.4
# 4          Freiburg  ...  13.8  0.0   0      0  2.3   2.3     0.19   1.7
#
#    np:G-xG  Match Report
# 0      NaN  Match Report
# 1     -0.8  Match Report
# ...

# %%
# combine the standings with shooting data
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time        Comp        Round  Day Venue Result   GF   GA  \
# 0  2023-08-12  15:30   DFB-Pokal  Round of 64  Sat  Away      W  6.0  1.0
# 1  2023-08-19  18:30  Bundesliga  Matchweek 1  Sat  Home      W  1.0  0.0
# 2  2023-08-26  15:30  Bundesliga  Matchweek 2  Sat  Away      D  1.0  1.0
# 3  2023-09-01  20:30  Bundesliga  Matchweek 3  Fri  Home      D  2.0  2.0
# 4  2023-09-16  15:30  Bundesliga  Matchweek 4  Sat  Away      W  4.0  2.0
#
#            Opponent  ...  Formation          Referee  Match Report  Notes  Sh  \
# 0  TSV Schott Mainz  ...    4-2-3-1   Benjamin Brand  Match Report    NaN  24
# 1              Köln  ...    4-2-3-1    Deniz Aytekin  Match Report    NaN  13
# 2            Bochum  ...    4-1-4-1  Robert Schröder  Match Report    NaN  14
# 3        Heidenheim  ...      4-3-3   Tobias Reichel  Match Report    NaN  18
# 4          Freiburg  ...      4-3-3   Tobias Stieler  Match Report    NaN  15
#
#   SoT  Dist   FK PK  PKatt
# ...

# %%
matches[0].shape
# Out:
# (49, 19)

# %%
shooting.shape
# Out:
# (43, 26)

# %%
# scraping for multiple seasons and teams
years = list(range(2024, 2022, -1))
years
# Out:
# [2024, 2023]

# %%
all_matches = []
standing_url = "https://fbref.com/en/comps/8/Champions-League-Stats"

# %%
for year in years:
  data = requests.get(standing_url)
  soup = BeautifulSoup(data.text)
  standings_table = soup.select('table.stats_table')[8]

  links = [l.get("href") for l in standings_table.find_all('a')]
  links = [l for l in links if '/squads/' in l]
  team_urls = [f"https://fbref.com{l}" for l in links]

  previous_season = soup.select("a.prev")[0].get("href")
  standings_url = f"https://fbref.com{previous_season}"

  for team_url in team_urls:
    team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")

    data = requests.get(team_url)
    matches = pd.read_html(data.text, match = "Scores & Fixtures")[0]

    soup = BeautifulSoup(data.text)
    links = [l.get("href") for l in soup.find_all('a')]
    links = [l for l in links if l and 'all_comps/shooting/' in l]
    data = requests.get(f"https://fbref.com{links[0]}")
    shooting = pd.read_html(data.text, match = "Shooting")[0]
    shooting.columns = shooting.columns.droplevel()

    try:
      team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
    except ValueError:
      continue

    team_data = team_data[team_data["Comp"] == "Champions Lg"] # filter the competition lvl
    team_data["Season"] = year
    team_data["Team"] = team_name
    all_matches.append(team_data)
    time.sleep(10) # do not request too quickly

# %%
match_df = pd.concat(all_matches) # combine individual df into one df

# %%
match_df
# Out:
#           Date   Time          Comp        Round  Day Venue Result   GF   GA  \
# 5   2023-09-19  21:00  Champions Lg  Group stage  Tue  Away      L  0.0  2.0
# 8   2023-10-04  21:00  Champions Lg  Group stage  Wed  Home      D  0.0  0.0
# 11  2023-10-25  20:00  Champions Lg  Group stage  Wed  Away      W  1.0  0.0
# 15  2023-11-07  18:45  Champions Lg  Group stage  Tue  Home      W  2.0  0.0
# 18  2023-11-28  21:00  Champions Lg  Group stage  Tue  Away      W  3.0  1.0
# ..         ...    ...           ...          ...  ...   ...    ...  ...  ...
# 9   2023-10-04  21:00  Champions Lg  Group stage  Wed  Home      D    2    2
# 12  2023-10-25  21:00  Champions Lg  Group stage  Wed  Away      L    1    3
# 16  2023-11-07  21:00  Champions Lg  Group stage  Tue  Home      L    1    2
# 19  2023-11-28  21:00  Champions Lg  Group stage  Tue  Away      L    0    2
# 22  2023-12-13  18:45  Champions Lg  Group stage  Wed  Home      L    2    3
#
# ...

# %%
match_df.to_csv("matches.csv")
